# %% [markdown]
# # **World Port Index Analysis**

# %% [markdown]
# ## **Introduction**
#
# The inspiration for the world's best port and terminal data analysis project came from wanting to venture past my comfort zone and gain insights into the backbone of logistics.
#
# This data analysis project's primary purpose is to pinpoint which major ports and terminals in the world excel above all those included in the dataset. The metrics, i.e., data fields, will be used to thoroughly reveal which ports have claimed top positions in terms of the various categories present in the dataset, which include location, physical characteristics, available facilities, and services offered. The analysis will also provide valuable insights for anyone interested in the maritime industry.
#
# The dataset was sourced from the National Geospatial-Intelligence Agency, a federal agency in the United States. The agency validates, updates, and maintains the data. The data is updated monthly.
#
# Link:  https://msi.nga.mill/Publications/WPI
# <br>   21/11/2022

# %% [markdown]
# #### Dataset sources
# Explanation of data fields
# <br> Link: https://msi.nga.mil/api/publications/download?key=16920959/SFH00000/WPI_Explanation_of_Data_Fields.pdf&type=view
# <br> Dataset
# <br> Link: https://msi.nga.mil/api/publications/download?type=view&key=16920959/SFH00000/UpdatedPub150.csv

# %%
from urllib import request
import camelot
import glob
import re
import zipfile
import pandas as pd

# %%
# This cell will download the dataset and explanation of the data fields to the current directory after providing the links above in third cell.
def get_data(URL):
    """ Download files from official website.  """
   
    if file_name := re.search("^https://msi\.nga\.mil/api/publications/download\?(?:.+)/SFH00000/(.+\.(csv|pdf))(.+)?", URL, re.IGNORECASE):
        request.urlretrieve(URL, file_name.group(1))
        print("Download successful")
    else:
        print("Error has occured")

get_data(input("Url: "))
# Out:
# Download successful

# %% [markdown]
# #### Generate a schema
# To avoid going back and forth between different applications, a schema to explain the data fields is generated for use.

# %%
def extract_tables(pdf_name):
    """
    Extract tables from WPI_Explanation_of_Data_Fields and compress them
    pdf_name: name of pdf to extract tables
    """
    explanation_tables = camelot.read_pdf(pdf_name, pages= "1, 2-9")
    explanation_tables.export("raw_schema.csv", f= "csv", compress= True)

    with zipfile.ZipFile("raw_schema.zip", "r") as zip_ref:
        return zip_ref.extractall("raw_schema")
    
extract_tables("WPI_Explanation_of_Data_Fields.pdf")

# %%
def merge_csv_files(path):
    """
    Merge all csv files into one from extracted tables from the pdf
    path: path of unzipped folder
    """
    merged_exp_tables = pd.concat(map(pd.read_csv, glob.glob(path + "/*.csv")), ignore_index= True)
    return merged_exp_tables.to_csv("preschema.csv", index= False)

 #path has to have double back slashes to work
merge_csv_files("C:\\Users\\DSL\\Documents\\python\\WPA\\raw_schema")

# %%
schema_df = pd.read_csv("preschema.csv", header= 0, names= ["Field_Name", "Description_of_Contents"])
schema_df.replace(r"\r+|\n+|\t+", "", regex= True, inplace= True)
schema_df
# Out:
#                             Field_Name  \
# 0                            OID [OID]
# 1               WPI Number [wpinumber]
# 2             Region Name [regionname]
# 3          Main Port Name [main_port_]
# 4    Alternate Port Name  [alternate_]
# ..                                 ...
# 104               Repairs [repair_cod]
# 105                Dry Dock [dry_dock]
# 106                  Railway [railway]
# 107                Latitude [Latitude]
# 108              Longitude [Longitude]
#
#                                Description_of_Contents
# 0    A common identifier is given for all entries i...
# 1    Each port and place contained in this dataset ...
# 2    Region Names, as given in the 2019 edition of ...
# 3    Main Port Name, with no diacritical marks.  In...
# 4    Alternate, conventional, or familiar names may...
# ..                                                 ...
# 104  Repairs that can be made to ocean-going vessel...
# 105  The general size and type of the largest under...
# 106  The general size and type of the largest under...
# 107                     Latitude of the port is given.
# 108                    Longitude of the port is given.
#
# [109 rows x 2 columns]

# %%
def clean_field_names(df):
    """
    Remove extra words from Field_Name in the schema in order to match them with data fields in the data set.
    df: Pandas data frame
    NB: Function can only be called after reading preschema csv with pandas
    """
    field_list = df["Field_Name"].tolist() # Convert specified column to a list
    modified_field_names = []
    try:
        for values in field_list: 
            if match := re.search("(.+)\[.+\]", values):
                modified_field_names.append(match.group(1).strip())

        #Replace current column with new generated column
        df["Field_Name"] = df["Field_Name"].replace(field_list, modified_field_names)
        return df

    except ValueError:
        print("Function can only be called after reading preschema csv as pandas dataframe as Field_name column has already been cleaned before.")

clean_field_names(schema_df)
schema_df.to_csv("schema.csv", index= False)

# %%
# Schema to refer to for the explanation of data fields in the dataset
schema_df = pd.read_csv("schema.csv", index_col= "Field_Name").Description_of_Contents
schema_df
# Out:
# Field_Name
# OID                    A common identifier is given for all entries i...
# WPI Number             Each port and place contained in this dataset ...
# Region Name            Region Names, as given in the 2019 edition of ...
# Main Port Name         Main Port Name, with no diacritical marks.  In...
# Alternate Port Name    Alternate, conventional, or familiar names may...
#                                              ...
# Repairs                Repairs that can be made to ocean-going vessel...
# Dry Dock               The general size and type of the largest under...
# Railway                The general size and type of the largest under...
# Latitude                                  Latitude of the port is given.
# Longitude                                Longitude of the port is given.
# Name: Description_of_Contents, Length: 109, dtype: object

# %%
schema_df["Channel Depth (m)"]
# Out:
# 'The controlling depth of the principal or deepest channel at chart datum is given.  The channel selected should lead up to the anchorage if within the harbor, or to the wharf/pier.  If the channel depth decreases from the anchorage to the wharf/pier and cargo can be worked at the anchorage, then the depth leading to the anchorage is given.'

# %% [markdown]
# ## **Data Wrangling**
#
# The dataset, UpdatedPub150.csv, consists of 3739 rows and 108 columns. Some columns will be discarded as they will not aid in any part of the analysis, leaving 90 columns. The dataset is clean, with no errors or duplicate records, and all formats have been standardized.

# %%
world_ports_raw_df = pd.read_csv("UpdatedPub150.csv")
world_ports_raw_df
# Out:
#       World Port Index Number                    Region Name  \
# 0                      7950.0  United States E Coast -- 6585
# 1                     52235.0              Sulawesi -- 51970
# 2                     47620.0            Madagascar -- 47350
# 3                     47360.0            Madagascar -- 47350
# 4                     47020.0              Tanzania -- 46965
# ...                       ...                            ...
# 3734                   1560.0  Newfoundland  E Coast -- 1410
# 3735                   1150.0
# 3736                   1260.0
# 3737                   1540.0  Newfoundland  E Coast -- 1410
# 3738                   1570.0  Newfoundland  E Coast -- 1410
#
#              Main Port Name Alternate Port Name UN/LOCODE   Country Code  \
# 0                    Maurer                                United States
# 1     Mangkasa Oil Terminal                                    Indonesia
# 2                   Iharana                                   Madagascar
# 3                   Andoany                                   Madagascar
# 4               Chake Chake                                     Tanzania
# ...                     ...                 ...       ...            ...
# 3734             Lewisporte                        CA LWP         Canada
# 3735          Deception Bay                        CA DEB         Canada
# 3736                   Nain                        CA NAI         Canada
# 3737                Botwood                        CA BWD         Canada
# 3738            Twillingate                        CA TWI         Canada
#
#                                 World Water Body IHO S-130 Sea Area  \
# 0                           North Atlantic Ocean
# 1     Teluk Bone; Banda Sea; South Pacific Ocean
# 2                                   Indian Ocean
# 3               Mozambique Channel; Indian Ocean
# 4                                   Indian Ocean
# ...                                          ...                ...
# 3734                        North Atlantic Ocean
# 3735                 Hudson Strait; Arctic Ocean
# 3736          Labrador Sea; North Atlantic Ocean
# 3737                        North Atlantic Ocean
# 3738                        North Atlantic Ocean
#
#                        Sailing Direction or Publication  \
# 0     U.S. Coast Pilot 2 - Atlantic Coast: Cape Cod ...
# 1     Sailing Directions Pub. 163 (Enroute) - Borneo...
# 2     Sailing Directions Pub. 171 (Enroute) - East A...
# 3     Sailing Directions Pub. 171 (Enroute) - East A...
# 4     Sailing Directions Pub. 171 (Enroute) - East A...
# ...                                                 ...
# 3734  Sailing Directions Pub. 146 (Enroute) - Newfou...
# 3735  Sailing Directions Pub. 146 (Enroute) - Newfou...
# 3736  Sailing Directions Pub. 146 (Enroute) - Newfou...
# 3737  Sailing Directions Pub. 146 (Enroute) - Newfou...
# 3738  Sailing Directions Pub. 146 (Enroute) - Newfou...
#
#                                        Publication Link  ...  \
# 0     https://nauticalcharts.noaa.gov/publications/c...  ...
# 1     https://msi.geo.nga.mil/api/publications/downl...  ...
# 2     https://msi.geo.nga.mil/api/publications/downl...  ...
# 3     https://msi.geo.nga.mil/api/publications/downl...  ...
# 4     https://msi.geo.nga.mil/api/publications/downl...  ...
# ...                                                 ...  ...
# 3734  https://msi.geo.nga.mil/api/publications/downl...  ...
# 3735  https://msi.geo.nga.mil/api/publications/downl...  ...
# 3736  https://msi.geo.nga.mil/api/publications/downl...  ...
# 3737  https://msi.geo.nga.mil/api/publications/downl...  ...
# 3738  https://msi.geo.nga.mil/api/publications/downl...  ...
#
#      Supplies - Fuel Oil Supplies - Diesel Oil Supplies - Aviation Fuel  \
# 0                    Yes                   Yes                  Unknown
# 1                     No                    No                  Unknown
# 2                     No                    No                  Unknown
# 3                     No                    No                  Unknown
# 4                     No                    No                  Unknown
# ...                  ...                   ...                      ...
# 3734                 Yes                   Yes                  Unknown
# 3735                 Yes                   Yes                  Unknown
# 3736             Unknown               Unknown                  Unknown
# 3737                 Yes                   Yes                  Unknown
# 3738                 Yes                   Yes                  Unknown
#
#      Supplies - Deck  Supplies - Engine         Repairs  Dry Dock  Railway  \
# 0                Yes                Yes        Moderate   Unknown  Unknown
# 1                 No                 No            None   Unknown  Unknown
# 2                 No                 No  Emergency Only   Unknown  Unknown
# 3                 No                 No  Emergency Only   Unknown  Unknown
# 4                 No                 No         Unknown   Unknown  Unknown
# ...              ...                ...             ...       ...      ...
# 3734         Unknown            Unknown         Limited     Small  Unknown
# 3735         Unknown            Unknown         Unknown   Unknown  Unknown
# 3736         Unknown            Unknown         Unknown   Unknown  Unknown
# 3737         Unknown            Unknown         Limited   Unknown  Unknown
# 3738         Unknown            Unknown         Limited   Unknown  Unknown
#
#        Latitude   Longitude
# 0     40.533333  -74.250000
# 1     -2.733333  121.066667
# 2    -13.350000   50.000000
# 3    -13.400000   48.300000
# 4     -5.250000   39.766667
# ...         ...         ...
# 3734  49.250000  -55.050000
# 3735  62.150000  -74.683333
# 3736  56.550000  -61.683333
# 3737  49.133333  -55.333333
# 3738  49.650000  -54.766667
#
# [3739 rows x 108 columns]

# %%
# Returns all data field names
world_ports_raw_df.columns.values
# Out:
# array(['World Port Index Number', 'Region Name', 'Main Port Name',
#        'Alternate Port Name', 'UN/LOCODE', 'Country Code',
#        'World Water Body', 'IHO S-130 Sea Area',
#        'Sailing Direction or Publication', 'Publication Link',
#        'Standard Nautical Chart',
#        'IHO S-57 Electronic Navigational Chart',
#        'IHO S-101 Electronic Navigational Chart',
#        'Digital Nautical Chart', 'Tidal Range (m)', 'Entrance Width (m)',
#        'Channel Depth (m)', 'Anchorage Depth (m)', 'Cargo Pier Depth (m)',
#        'Oil Terminal Depth (m)',
#        'Liquified Natural Gas Terminal Depth (m)',
#        'Maximum Vessel Length (m)', 'Maximum Vessel Beam (m)',
#        'Maximum Vessel Draft (m)', 'Offshore Maximum Vessel Length (m)',
#        'Offshore Maximum Vessel Beam (m)',
#        'Offshore Maximum Vessel Draft (m)', 'Harbor Size', 'Harbor Type',
#        'Harbor Use', 'Shelter Afforded', 'Entrance Restriction - Tide',
#        'Entrance Restriction - Heavy Swell', 'Entrance Restriction - Ice',
#        'Entrance Restriction - Other', 'Overhead Limits',
#        'Underkeel Clearance Management System', 'Good Holding Ground',
#        'Turning Area', 'Port Security',
#        'Estimated Time of Arrival Message', 'Quarantine - Pratique',
#        'Quarantine - Sanitation', 'Quarantine - Other',
#        'Traffic Separation Scheme', 'Vessel Traffic Service',
#        'First Port of Entry', 'US Representative',
#        'Pilotage - Compulsory', 'Pilotage - Available',
#        'Pilotage - Local Assistance', 'Pilotage - Advisable',
#        'Tugs - Salvage', 'Tugs - Assistance',
#        'Communications - Telephone', 'Communications - Telefax',
#        'Communications - Radio', 'Communications - Radiotelephone',
#        'Communications - Airport', 'Communications - Rail',
#        'Search and Rescue', 'NAVAREA', 'Facilities - Wharves',
#        'Facilities - Anchorage', 'Facilities - Dangerous Cargo Anchorage',
#        'Facilities - Med Mooring', 'Facilities - Beach Mooring',
#        'Facilities - Ice Mooring', 'Facilities - Ro-Ro',
#        'Facilities - Solid Bulk', 'Facilities - Liquid Bulk',
#        'Facilities - Container', 'Facilities - Breakbulk',
#        'Facilities - Oil Terminal', 'Facilities - LNG Terminal',
#        'Facilities - Other', 'Medical Facilities', 'Garbage Disposal',
#        'Chemical Holding Tank Disposal', 'Degaussing',
#        'Dirty Ballast Disposal', 'Cranes - Fixed', 'Cranes - Mobile',
#        'Cranes - Floating', 'Cranes - Container', 'Lifts - 100+ Tons',
#        'Lifts - 50-100 Tons', 'Lifts - 25-49 Tons', 'Lifts - 0-24 Tons',
#        'Services - Longshoremen', 'Services - Electricity',
#        'Services - Steam', 'Services - Navigation Equipment',
#        'Services - Electrical Repair', 'Services - Ice Breaking',
#        'Services - Diving', 'Supplies - Provisions',
#        'Supplies - Potable Water', 'Supplies - Fuel Oil',
#        'Supplies - Diesel Oil', 'Supplies - Aviation Fuel',
#        'Supplies - Deck', 'Supplies - Engine', 'Repairs', 'Dry Dock',
#        'Railway', 'Latitude', 'Longitude'], dtype=object)

# %%
selected_columns = [
# General Port information
"World Port Index Number",
"Region Name",
"Main Port Name",
"Alternate Port Name",
"UN/LOCODE",
"Country Code",
"World Water Body",
"IHO S-130 Sea Area",
'Entrance Width (m)',
'Channel Depth (m)', 
'Anchorage Depth (m)',
'Cargo Pier Depth (m)',
'Oil Terminal Depth (m)',
'Maximum Vessel Length (m)', 
'Maximum Vessel Beam (m)',
'Maximum Vessel Draft (m)',
'Offshore Maximum Vessel Length (m)',
'Offshore Maximum Vessel Beam (m)',
'Offshore Maximum Vessel Draft (m)',
'Harbor Size', 
'Harbor Type',
'Harbor Use',
# Limitations present (values; Yes, No, Unknown)
'Entrance Restriction - Tide',
'Entrance Restriction - Heavy Swell', 
'Entrance Restriction - Ice',
'Entrance Restriction - Other',
'Overhead Limits',
# Systems in place
'Good Holding Ground',
'Turning Area',
'Shelter Afforded',
'Port Security',
'Estimated Time of Arrival Message', 
'Quarantine - Pratique',
'Quarantine - Sanitation', 
'Quarantine - Other',
'Traffic Separation Scheme', 
'Vessel Traffic Service',
# Critical infrastructure avaiilable (values; Yes, No, Unknown)
'Tugs - Salvage', 
'Tugs - Assistance',
'Communications - Telephone', 
'Communications - Telefax',
'Communications - Radio', 
'Communications - Radiotelephone',
'Communications - Airport', 
'Communications - Rail',
'Search and Rescue',
# Facilities available (values; Yes, No, Unknown)
'Facilities - Wharves',
'Facilities - Anchorage', 
'Facilities - Dangerous Cargo Anchorage',
'Facilities - Med Mooring', 
'Facilities - Beach Mooring',
'Facilities - Ice Mooring', 
'Facilities - Ro-Ro',
'Facilities - Solid Bulk', 
'Facilities - Liquid Bulk',
'Facilities - Container', 
'Facilities - Breakbulk',
'Facilities - Oil Terminal', 
'Facilities - LNG Terminal',
'Facilities - Other',
'Medical Facilities', 
'Garbage Disposal',
'Chemical Holding Tank Disposal', 
'Degaussing',
'Dirty Ballast Disposal',
# Equipment availability (values; Yes, No, Unknown)
'Cranes - Fixed', 
'Cranes - Mobile',
'Cranes - Floating', 
'Cranes - Container', 
'Lifts - 100+ Tons',
'Lifts - 50-100 Tons', 
'Lifts - 25-49 Tons', 
'Lifts - 0-24 Tons',
# Complimentary services availabity (values; Yes, No, Unknown)
'Services - Longshoremen', 
'Services - Electricity',
'Services - Steam', 
'Services - Navigation Equipment',
'Services - Electrical Repair', 
'Services - Ice Breaking',
'Services - Diving',
# General supplies availabilty (values; Yes, No, Unknown)
'Supplies - Provisions',
'Supplies - Potable Water', 
'Supplies - Fuel Oil',
'Supplies - Diesel Oil', 
'Supplies - Aviation Fuel',
'Supplies - Deck', 
'Supplies - Engine',
# Repair services
'Repairs',
'Dry Dock',
'Railway'
]

len(selected_columns)
# Out:
# 90

# %%
# Generate a copy of the dataframe
preworld_ports_df = world_ports_raw_df[selected_columns].copy() 
preworld_ports_df
# Out:
#       World Port Index Number                    Region Name  \
# 0                      7950.0  United States E Coast -- 6585
# 1                     52235.0              Sulawesi -- 51970
# 2                     47620.0            Madagascar -- 47350
# 3                     47360.0            Madagascar -- 47350
# 4                     47020.0              Tanzania -- 46965
# ...                       ...                            ...
# 3734                   1560.0  Newfoundland  E Coast -- 1410
# 3735                   1150.0
# 3736                   1260.0
# 3737                   1540.0  Newfoundland  E Coast -- 1410
# 3738                   1570.0  Newfoundland  E Coast -- 1410
#
#              Main Port Name Alternate Port Name UN/LOCODE   Country Code  \
# 0                    Maurer                                United States
# 1     Mangkasa Oil Terminal                                    Indonesia
# 2                   Iharana                                   Madagascar
# 3                   Andoany                                   Madagascar
# 4               Chake Chake                                     Tanzania
# ...                     ...                 ...       ...            ...
# 3734             Lewisporte                        CA LWP         Canada
# 3735          Deception Bay                        CA DEB         Canada
# 3736                   Nain                        CA NAI         Canada
# 3737                Botwood                        CA BWD         Canada
# 3738            Twillingate                        CA TWI         Canada
#
#                                 World Water Body IHO S-130 Sea Area  \
# 0                           North Atlantic Ocean
# 1     Teluk Bone; Banda Sea; South Pacific Ocean
# 2                                   Indian Ocean
# 3               Mozambique Channel; Indian Ocean
# 4                                   Indian Ocean
# ...                                          ...                ...
# 3734                        North Atlantic Ocean
# 3735                 Hudson Strait; Arctic Ocean
# 3736          Labrador Sea; North Atlantic Ocean
# 3737                        North Atlantic Ocean
# 3738                        North Atlantic Ocean
#
#       Entrance Width (m)  Channel Depth (m)  ...  Supplies - Provisions  \
# 0                    0.0               11.0  ...                    Yes
# 1                    0.0                9.4  ...                     No
# 2                    0.0               14.0  ...                    Yes
# 3                    0.0               20.1  ...                Unknown
# 4                    0.0               14.0  ...                     No
# ...                  ...                ...  ...                    ...
# 3734                 0.0                0.0  ...                    Yes
# 3735                 0.0                0.0  ...                Unknown
# 3736                 0.0                0.0  ...                Unknown
# 3737                 0.0                0.0  ...                    Yes
# 3738                 0.0                0.0  ...                Unknown
#
#       Supplies - Potable Water  Supplies - Fuel Oil  Supplies - Diesel Oil  \
# 0                          Yes                  Yes                    Yes
# 1                           No                   No                     No
# 2                          Yes                   No                     No
# 3                          Yes                   No                     No
# 4                           No                   No                     No
# ...                        ...                  ...                    ...
# 3734                       Yes                  Yes                    Yes
# 3735                       Yes                  Yes                    Yes
# 3736                   Unknown              Unknown                Unknown
# 3737                       Yes                  Yes                    Yes
# 3738                       Yes                  Yes                    Yes
#
#       Supplies - Aviation Fuel  Supplies - Deck  Supplies - Engine  \
# 0                      Unknown              Yes                Yes
# 1                      Unknown               No                 No
# 2                      Unknown               No                 No
# 3                      Unknown               No                 No
# 4                      Unknown               No                 No
# ...                        ...              ...                ...
# 3734                   Unknown          Unknown            Unknown
# 3735                   Unknown          Unknown            Unknown
# 3736                   Unknown          Unknown            Unknown
# 3737                   Unknown          Unknown            Unknown
# 3738                   Unknown          Unknown            Unknown
#
#              Repairs  Dry Dock  Railway
# 0           Moderate   Unknown  Unknown
# 1               None   Unknown  Unknown
# 2     Emergency Only   Unknown  Unknown
# 3     Emergency Only   Unknown  Unknown
# 4            Unknown   Unknown  Unknown
# ...              ...       ...      ...
# 3734         Limited     Small  Unknown
# 3735         Unknown   Unknown  Unknown
# 3736         Unknown   Unknown  Unknown
# 3737         Limited   Unknown  Unknown
# 3738         Limited   Unknown  Unknown
#
# [3739 rows x 90 columns]

# %% [markdown]
# ### **Data Integration**
#
# To answer the posed questions, a new dataset had to be introduced to aid in the analysis by merging them.

# %%
countries_continents_df = pd.read_csv("Countries-Continents.txt")
countries_continents_df
# Out:
#          Continent    Country
# 0           Africa    Algeria
# 1           Africa     Angola
# 2           Africa      Benin
# 3           Africa   Botswana
# 4           Africa    Burkina
# ..             ...        ...
# 189  South America   Paraguay
# 190  South America       Peru
# 191  South America   Suriname
# 192  South America    Uruguay
# 193  South America  Venezuela
#
# [194 rows x 2 columns]

# %%
# Merging the two datasets 
world_ports_df = pd.merge(preworld_ports_df, countries_continents_df, 
                        left_on="Country Code",
                        right_on = "Country",
                        how = "left")
world_ports_df
# Out:
#       World Port Index Number                    Region Name  \
# 0                      7950.0  United States E Coast -- 6585
# 1                     52235.0              Sulawesi -- 51970
# 2                     47620.0            Madagascar -- 47350
# 3                     47360.0            Madagascar -- 47350
# 4                     47020.0              Tanzania -- 46965
# ...                       ...                            ...
# 3734                   1560.0  Newfoundland  E Coast -- 1410
# 3735                   1150.0
# 3736                   1260.0
# 3737                   1540.0  Newfoundland  E Coast -- 1410
# 3738                   1570.0  Newfoundland  E Coast -- 1410
#
#              Main Port Name Alternate Port Name UN/LOCODE   Country Code  \
# 0                    Maurer                                United States
# 1     Mangkasa Oil Terminal                                    Indonesia
# 2                   Iharana                                   Madagascar
# 3                   Andoany                                   Madagascar
# 4               Chake Chake                                     Tanzania
# ...                     ...                 ...       ...            ...
# 3734             Lewisporte                        CA LWP         Canada
# 3735          Deception Bay                        CA DEB         Canada
# 3736                   Nain                        CA NAI         Canada
# 3737                Botwood                        CA BWD         Canada
# 3738            Twillingate                        CA TWI         Canada
#
#                                 World Water Body IHO S-130 Sea Area  \
# 0                           North Atlantic Ocean
# 1     Teluk Bone; Banda Sea; South Pacific Ocean
# 2                                   Indian Ocean
# 3               Mozambique Channel; Indian Ocean
# 4                                   Indian Ocean
# ...                                          ...                ...
# 3734                        North Atlantic Ocean
# 3735                 Hudson Strait; Arctic Ocean
# 3736          Labrador Sea; North Atlantic Ocean
# 3737                        North Atlantic Ocean
# 3738                        North Atlantic Ocean
#
#       Entrance Width (m)  Channel Depth (m)  ...  Supplies - Fuel Oil  \
# 0                    0.0               11.0  ...                  Yes
# 1                    0.0                9.4  ...                   No
# 2                    0.0               14.0  ...                   No
# 3                    0.0               20.1  ...                   No
# 4                    0.0               14.0  ...                   No
# ...                  ...                ...  ...                  ...
# 3734                 0.0                0.0  ...                  Yes
# 3735                 0.0                0.0  ...                  Yes
# 3736                 0.0                0.0  ...              Unknown
# 3737                 0.0                0.0  ...                  Yes
# 3738                 0.0                0.0  ...                  Yes
#
#       Supplies - Diesel Oil  Supplies - Aviation Fuel  Supplies - Deck  \
# 0                       Yes                   Unknown              Yes
# 1                        No                   Unknown               No
# 2                        No                   Unknown               No
# 3                        No                   Unknown               No
# 4                        No                   Unknown               No
# ...                     ...                       ...              ...
# 3734                    Yes                   Unknown          Unknown
# 3735                    Yes                   Unknown          Unknown
# 3736                Unknown                   Unknown          Unknown
# 3737                    Yes                   Unknown          Unknown
# 3738                    Yes                   Unknown          Unknown
#
#       Supplies - Engine         Repairs  Dry Dock  Railway      Continent  \
# 0                   Yes        Moderate   Unknown  Unknown            NaN
# 1                    No            None   Unknown  Unknown           Asia
# 2                    No  Emergency Only   Unknown  Unknown         Africa
# 3                    No  Emergency Only   Unknown  Unknown         Africa
# 4                    No         Unknown   Unknown  Unknown         Africa
# ...                 ...             ...       ...      ...            ...
# 3734            Unknown         Limited     Small  Unknown  North America
# 3735            Unknown         Unknown   Unknown  Unknown  North America
# 3736            Unknown         Unknown   Unknown  Unknown  North America
# 3737            Unknown         Limited   Unknown  Unknown  North America
# 3738            Unknown         Limited   Unknown  Unknown  North America
#
#          Country
# 0            NaN
# 1      Indonesia
# 2     Madagascar
# 3     Madagascar
# 4       Tanzania
# ...          ...
# 3734      Canada
# 3735      Canada
# 3736      Canada
# 3737      Canada
# 3738      Canada
#
# [3739 rows x 92 columns]

# %%
world_ports_df.to_csv("Major Ports & Terminals Analysis.csv", index= False)
